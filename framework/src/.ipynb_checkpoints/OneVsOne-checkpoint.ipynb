# %%
# !pip install mord
# Out:
# Collecting mord
#   Downloading mord-0.7.tar.gz (8.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: mord
#   Building wheel for mord (setup.py): started
#   Building wheel for mord (setup.py): finished with status 'done'
#   Created wheel for mord: filename=mord-0.7-py3-none-any.whl size=9890 sha256=8ce71812f04dfaafea422cea8d9130d13c4d2a86e3bd627d220a1a0b3b6fe493
#   Stored in directory: c:\users\lassa\appdata\local\pip\cache\wheels\bb\62\6d\f94a319e6f1bd5a8c0dd093afdd390b0e361710ed06ba7f3e3
# Successfully built mord
# Installing collected packages: mord
# Successfully installed mord-0.7

# %%
import pandas as pd
import numpy as np
import glob
from multiprocessing import cpu_count
from experiment_tools import *
working_path = "C:\\Users\\lassa\\OneDrive\\Desktop\\workspace\\VICTIMS_OF_FALL_MASTER_THESIS"

# %%
# %%time
import json

#This block run all the experiments
files = glob.glob(f"{working_path}\\input_exp\\default_models\\OneVsOne\\*.json")
for file in files:
    print(file)
    with open (file, "r") as f:
        data=f.read().replace('\n', '')
    splits = file.split("\\")
    experiment_name = splits[-1].split(".")[0]
    experiment_setup = json.loads(data)
    print(f"EXECUTION OF THE EXPERIMENT {experiment_name}")
    Experiment().experiment(working_path, "results\\default_models\\OneVsOne", experiment_name, experiment_setup, "victims_of_fall_V2")
# Out:
# C:\Users\lassa\OneDrive\Desktop\workspace\VICTIMS_OF_FALL_MASTER_THESIS\input_exp\default_models\OneVsOne\OneVsOne - DecisionTreeClassifier.json
# EXECUTION OF THE EXPERIMENT OneVsOne - DecisionTreeClassifier
# complete
# n_iter:100
# Fitting 10 folds for each of 48 candidates, totalling 480 fits
# C:\Users\lassa\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:307: UserWarning: The total space of parameters 48 is smaller than n_iter=100. Running 48 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(

# %%
 #This block acquire all the results obtained
import json
files = glob.glob(f"{working_path}\\results\\default_models\\binary-classifiers\\*.json")

filter_floor_labels = True

all_experiments_results = []
for i, file in enumerate(files):
    with open (file, "r") as f:
        
        data=f.read().replace('\n', '')
        experiment_results = json.loads(data)
        
        if type(experiment_results) == dict:
            experiment_results = [experiment_results]
            
        all_experiments_results.append(pd.DataFrame(experiment_results))

df = pd.concat(all_experiments_results)
df = df.reset_index().drop('index', axis = 1)
df["Dataset"]="Version 1"

# %%
 #This block acquire all the results obtained
import json
files = glob.glob(f"{working_path}\\results\\exp_V2\\binary-classifiers\\*.json")
filter_floor_labels = True

all_experiments_results = []
for i, file in enumerate(files):
    with open (file, "r") as f:
        
        data=f.read().replace('\n', '')
        experiment_results = json.loads(data)
        
        if type(experiment_results) == dict:
            experiment_results = [experiment_results]
            
        all_experiments_results.append(pd.DataFrame(experiment_results))

df2 = pd.concat(all_experiments_results)
df2 = df2.reset_index().drop('index', axis = 1)
df2["Dataset"]="Version 2"

# %%
df = pd.concat([df,df2])

# %%
filter_dict = {"task" : "Regression", "cv_type" : "n_split_inner_cv"}
target_metric = "neg_root_mean_squared_error"
filtered_df = df
for k, v in filter_dict.items():
    filtered_df = filtered_df.loc[filtered_df[k] == v]

filtered_df = filtered_df.reset_index().drop('index', axis = 1)
filtered_df = filtered_df.sort_values(by = 'mean_test_score', axis=0, ascending = False, key=lambda x: x.apply(lambda y: y[target_metric]))

# %%
filter_dict = {"task" : "Classification", "cv_type" : "n_split_inner_cv"}
target_metric = "accuracy"
filtered_df = df
for k, v in filter_dict.items():
    filtered_df = filtered_df.loc[filtered_df[k] == v]

filtered_df = filtered_df.reset_index().drop('index', axis = 1)
filtered_df = filtered_df.sort_values(by = 'mean_test_score', axis=0, ascending = False, key=lambda x: x.apply(lambda y: y[target_metric]))

# %%
#USED TO ADD FLOOR THRESHOLD IN CLASSIFICATION TASK
floor_thresholds = []
for i,v in filtered_df.iterrows():
    v = v['experiment_setup']
    v = str(v).replace("'","\"")
    experiment_setup = json.loads(v)
    print((i,b))
    b = experiment_setup["dataset_settings"]['binarize']
    filtered_df.at[i,'Floor Threshold'] = str(b[0])
# Out:
# (43, [4])
# (59, [6])
# (58, [6])
# (57, [6])
# (100, [6])
# (119, [6])
# (118, [6])
# (149, [6])
# (74, [6])
# (72, [6])
# (42, [6])
# (117, [6])
# (136, [6])
# (133, [2])
# (44, [6])
# (73, [6])
# (147, [6])
# (101, [6])
# (132, [6])
# (61, [6])
# (26, [2])
# (148, [6])
# (135, [6])
# (134, [2])
# (25, [6])
# (137, [6])
# (99, [2])
# (107, [6])
# (24, [2])
# (106, [6])
# (120, [2])
# (87, [2])
# (60, [6])
# (31, [2])
# (91, [2])
# (122, [2])
# (45, [2])
# (92, [2])
# (90, [2])
# (32, [2])
# (55, [2])
# (14, [5])
# (56, [6])
# (62, [5])
# (47, [2])
# (16, [2])
# (30, [2])
# (121, [2])
# (105, [2])
# (88, [2])
# (69, [6])
# (46, [5])
# (12, [2])
# (54, [6])
# (34, [5])
# (89, [3])
# (17, [6])
# (70, [2])
# (13, [5])
# (76, [6])
# (15, [2])
# (0, [2])
# (145, [2])
# (33, [5])
# (144, [3])
# (67, [5])
# (19, [4])
# (139, [3])
# (71, [3])
# (129, [5])
# (108, [5])
# (130, [3])
# (94, [5])
# (138, [3])
# (93, [3])
# (131, [3])
# (18, [5])
# (40, [3])
# (111, [5])
# (109, [4])
# (75, [3])
# (115, [2])
# (65, [5])
# (35, [3])
# (110, [3])
# (64, [3])
# (116, [3])
# (1, [5])
# (27, [2])
# (63, [5])
# (104, [3])
# (96, [5])
# (41, [4])
# (49, [5])
# (48, [3])
# (36, [3])
# (146, [4])
# (39, [5])
# (29, [5])
# (28, [5])
# (114, [5])
# (77, [5])
# (97, [2])
# (124, [4])
# (2, [3])
# (37, [2])
# (140, [4])
# (123, [3])
# (38, [3])
# (22, [4])
# (66, [4])
# (141, [4])
# (112, [4])
# (142, [4])
# (3, [4])
# (95, [3])
# (102, [3])
# (51, [5])
# (103, [4])
# (20, [5])
# (50, [3])
# (52, [3])
# (125, [4])
# (128, [3])
# (113, [4])
# (68, [4])
# (127, [4])
# (126, [4])
# (11, [4])
# (143, [5])
# (21, [4])
# (8, [4])
# (53, [4])
# (23, [4])
# (98, [4])
# (80, [4])
# (84, [3])
# (78, [5])
# (9, [3])
# (79, [5])
# (86, [3])
# (5, [5])
# (10, [3])
# (82, [5])
# (7, [4])
# (83, [4])
# (4, [4])
# (81, [3])
# (85, [4])
# (6, [5])
# C:\Users\lassa\AppData\Local\Temp\ipykernel_21988\1431021332.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   filtered_df.at[i,'Floor Threshold'] = str(b[0])

# %%
filtered_df
# Out:
#                     experiment_name dataset_variant  \
# 43      RandomForrestClassifier - 6     only_totals
# 59              RidgeClassifier - 6     only_binary
# 58              RidgeClassifier - 6     only_totals
# 57              RidgeClassifier - 6        complete
# 100  GradientBoostingClassifier - 6     only_totals
# ..                              ...             ...
# 83        DecisionTreeRegressor - 4     only_binary
# 4         DecisionTreeRegressor - 3     only_totals
# 81        DecisionTreeRegressor - 4        complete
# 85        DecisionTreeRegressor - 5     only_totals
# 6         DecisionTreeRegressor - 4        complete
#
#                         estimator            task       hp_optimizer  \
# 43       RandomForestClassifier()  Classification  RandomizeSearchCV
# 59              RidgeClassifier()  Classification  RandomizeSearchCV
# 58              RidgeClassifier()  Classification  RandomizeSearchCV
# 57              RidgeClassifier()  Classification  RandomizeSearchCV
# 100  GradientBoostingClassifier()  Classification  RandomizeSearchCV
# ..                            ...             ...                ...
# 83       DecisionTreeClassifier()  Classification  RandomizeSearchCV
# 4        DecisionTreeClassifier()  Classification  RandomizeSearchCV
# 81       DecisionTreeClassifier()  Classification  RandomizeSearchCV
# 85       DecisionTreeClassifier()  Classification  RandomizeSearchCV
# 6        DecisionTreeClassifier()  Classification  RandomizeSearchCV
#
#               cv_type                                    mean_test_score  \
# 43   n_split_inner_cv  {'accuracy': 0.8592436974789915, 'f1_micro': 0...
# 59   n_split_inner_cv  {'accuracy': 0.8592436974789915, 'f1_micro': 0...
# 58   n_split_inner_cv  {'accuracy': 0.8592436974789915, 'f1_micro': 0...
# 57   n_split_inner_cv  {'accuracy': 0.8592436974789915, 'f1_micro': 0...
# 100  n_split_inner_cv  {'accuracy': 0.8570731707317073, 'f1_micro': 0...
# ..                ...                                                ...
# 83   n_split_inner_cv  {'accuracy': 0.6742682926829268, 'f1_micro': 0...
# 4    n_split_inner_cv  {'accuracy': 0.6684033613445379, 'f1_micro': 0...
# 81   n_split_inner_cv  {'accuracy': 0.6596341463414634, 'f1_micro': 0...
# 85   n_split_inner_cv  {'accuracy': 0.651280487804878, 'f1_micro': 0....
# 6    n_split_inner_cv  {'accuracy': 0.6478151260504201, 'f1_micro': 0...
#
#                                       mean_train_score  \
# 43   {'accuracy': 1.0, 'f1_micro': 1.0, 'f1_macro':...
# 59   {'accuracy': 0.8608673436801432, 'f1_micro': 0...
# 58   {'accuracy': 0.8598890804964766, 'f1_micro': 0...
# 57   {'accuracy': 0.8664090609099233, 'f1_micro': 0...
# 100  {'accuracy': 0.9709167544783984, 'f1_micro': 0...
# ..                                                 ...
# 83   {'accuracy': 1.0, 'f1_micro': 1.0, 'f1_macro':...
# 4    {'accuracy': 1.0, 'f1_micro': 1.0, 'f1_macro':...
# 81   {'accuracy': 1.0, 'f1_micro': 1.0, 'f1_macro':...
# 85   {'accuracy': 0.9978059611621257, 'f1_micro': 0...
# 6    {'accuracy': 1.0, 'f1_micro': 1.0, 'f1_macro':...
#
#                                            best_params  \
# 43   [{'feature_extraction__n_components': 1, 'feat...
# 59   [{'feature_extraction__n_components': 14, 'fea...
# 58   [{'feature_extraction__n_components': 1, 'feat...
# 57   [{'feature_extraction__n_components': 20, 'fea...
# 100  [{'feature_extraction__n_components': 2, 'feat...
# ..                                                 ...
# 83   [{'feature_extraction__n_components': 8, 'feat...
# 4    [{'feature_extraction__n_components': 1, 'feat...
# 81   [{'feature_extraction__n_components': 12, 'fea...
# 85   [{'feature_extraction__n_components': 2, 'feat...
# 6    [{'feature_extraction__n_components': 1, 'feat...
#
#                                             cv_results  \
# 43   {'fit_time': array([11.8899281 , 12.20472836, ...
# 59   {'fit_time': array([3.82246614, 3.91271973, 3....
# 58   {'fit_time': array([0.83096766, 0.8104291 , 0....
# 57   {'fit_time': array([5.45679998, 5.45379925, 5....
# 100  {'fit_time': array([8.95311832, 8.79779291, 8....
# ..                                                 ...
# 83   {'fit_time': array([4.94725227, 4.79813504, 4....
# 4    {'fit_time': array([0.85793138, 0.79529262, 0....
# 81   {'fit_time': array([6.58462286, 6.7140131 , 6....
# 85   {'fit_time': array([0.86878991, 0.88280368, 0....
# 6    {'fit_time': array([6.11654139, 6.1371901 , 6....
#
#                                       experiment_setup    Dataset  \
# 43   {'dataset_settings': {'dataset_variants': ['co...  Version 1
# 59   {'dataset_settings': {'dataset_variants': ['co...  Version 1
# 58   {'dataset_settings': {'dataset_variants': ['co...  Version 1
# 57   {'dataset_settings': {'dataset_variants': ['co...  Version 1
# 100  {'dataset_settings': {'dataset_variants': ['co...  Version 2
# ..                                                 ...        ...
# 83   {'dataset_settings': {'dataset_variants': ['co...  Version 2
# 4    {'dataset_settings': {'dataset_variants': ['co...  Version 1
# 81   {'dataset_settings': {'dataset_variants': ['co...  Version 2
# 85   {'dataset_settings': {'dataset_variants': ['co...  Version 2
# 6    {'dataset_settings': {'dataset_variants': ['co...  Version 1
#
#     Floor Threshold
# 43                6
# 59                6
# 58                6
# 57                6
# 100               6
# ..              ...
# 83                4
# 4                 3
# 81                4
# 85                5
# 6                 4
#
# [150 rows x 13 columns]

# %%
from numpy import array
#THIS IS USED TO EXPLODE THE DICT OF THE SCORES AS COLUMNS OF THE RESULTED FILTERED_DF
values = {}
df_table = filtered_df[:0]
estimators = {}
for index, record in filtered_df.iterrows():
    cv_result = record.cv_results

    i_scoring = cv_result.rfind("scoring")
    i_test = cv_result[i_scoring:].find("'test")
    cv_result = "{"+cv_result[i_scoring+i_test:]
    cv_result = eval(cv_result)
    
    for k, list_scores in cv_result.items():
        if values.get(k) == None:
            values[k] = []
        mean = np.round(np.mean(np.abs(list_scores)), 2)
        std = np.round(np.std(np.abs(list_scores)), 2)
        
        values[k].append(str(mean)+" (std. "+str(std)+")")
    
for k, v in values.items():
    filtered_df[k] = v

# %%
#THIS IS USED TO EXPLODE THE DICT OF THE SCORES AS COLUMNS OF THE RESULTED FILTERED_DF
values = {}
for record in filtered_df.mean_test_score:
    for k, v in record.items():
        if values.get(k) == None:
            values[k] = []
        values[k].append(v)

for k, v in values.items():
    filtered_df[k] = v

# %%
filtered_df
# Out:
#                     experiment_name dataset_variant  \
# 43      RandomForrestClassifier - 6     only_totals
# 59              RidgeClassifier - 6     only_binary
# 58              RidgeClassifier - 6     only_totals
# 57              RidgeClassifier - 6        complete
# 100  GradientBoostingClassifier - 6     only_totals
# ..                              ...             ...
# 83        DecisionTreeRegressor - 4     only_binary
# 4         DecisionTreeRegressor - 3     only_totals
# 81        DecisionTreeRegressor - 4        complete
# 85        DecisionTreeRegressor - 5     only_totals
# 6         DecisionTreeRegressor - 4        complete
#
#                         estimator            task       hp_optimizer  \
# 43       RandomForestClassifier()  Classification  RandomizeSearchCV
# 59              RidgeClassifier()  Classification  RandomizeSearchCV
# 58              RidgeClassifier()  Classification  RandomizeSearchCV
# 57              RidgeClassifier()  Classification  RandomizeSearchCV
# 100  GradientBoostingClassifier()  Classification  RandomizeSearchCV
# ..                            ...             ...                ...
# 83       DecisionTreeClassifier()  Classification  RandomizeSearchCV
# 4        DecisionTreeClassifier()  Classification  RandomizeSearchCV
# 81       DecisionTreeClassifier()  Classification  RandomizeSearchCV
# 85       DecisionTreeClassifier()  Classification  RandomizeSearchCV
# 6        DecisionTreeClassifier()  Classification  RandomizeSearchCV
#
#               cv_type                                    mean_test_score  \
# 43   n_split_inner_cv  {'accuracy': 0.8592436974789915, 'f1_micro': 0...
# 59   n_split_inner_cv  {'accuracy': 0.8592436974789915, 'f1_micro': 0...
# 58   n_split_inner_cv  {'accuracy': 0.8592436974789915, 'f1_micro': 0...
# 57   n_split_inner_cv  {'accuracy': 0.8592436974789915, 'f1_micro': 0...
# 100  n_split_inner_cv  {'accuracy': 0.8570731707317073, 'f1_micro': 0...
# ..                ...                                                ...
# 83   n_split_inner_cv  {'accuracy': 0.6742682926829268, 'f1_micro': 0...
# 4    n_split_inner_cv  {'accuracy': 0.6684033613445379, 'f1_micro': 0...
# 81   n_split_inner_cv  {'accuracy': 0.6596341463414634, 'f1_micro': 0...
# 85   n_split_inner_cv  {'accuracy': 0.651280487804878, 'f1_micro': 0....
# 6    n_split_inner_cv  {'accuracy': 0.6478151260504201, 'f1_micro': 0...
#
#                                       mean_train_score  \
# 43   {'accuracy': 1.0, 'f1_micro': 1.0, 'f1_macro':...
# 59   {'accuracy': 0.8608673436801432, 'f1_micro': 0...
# 58   {'accuracy': 0.8598890804964766, 'f1_micro': 0...
# 57   {'accuracy': 0.8664090609099233, 'f1_micro': 0...
# 100  {'accuracy': 0.9709167544783984, 'f1_micro': 0...
# ..                                                 ...
# 83   {'accuracy': 1.0, 'f1_micro': 1.0, 'f1_macro':...
# 4    {'accuracy': 1.0, 'f1_micro': 1.0, 'f1_macro':...
# 81   {'accuracy': 1.0, 'f1_micro': 1.0, 'f1_macro':...
# 85   {'accuracy': 0.9978059611621257, 'f1_micro': 0...
# 6    {'accuracy': 1.0, 'f1_micro': 1.0, 'f1_macro':...
#
#                                            best_params  \
# 43   [{'feature_extraction__n_components': 1, 'feat...
# 59   [{'feature_extraction__n_components': 14, 'fea...
# 58   [{'feature_extraction__n_components': 1, 'feat...
# 57   [{'feature_extraction__n_components': 20, 'fea...
# 100  [{'feature_extraction__n_components': 2, 'feat...
# ..                                                 ...
# 83   [{'feature_extraction__n_components': 8, 'feat...
# 4    [{'feature_extraction__n_components': 1, 'feat...
# 81   [{'feature_extraction__n_components': 12, 'fea...
# 85   [{'feature_extraction__n_components': 2, 'feat...
# 6    [{'feature_extraction__n_components': 1, 'feat...
#
#                                             cv_results  ...    train_f1_macro  \
# 43   {'fit_time': array([11.8899281 , 12.20472836, ...  ...    1.0 (std. 0.0)
# 59   {'fit_time': array([3.82246614, 3.91271973, 3....  ...  0.48 (std. 0.01)
# 58   {'fit_time': array([0.83096766, 0.8104291 , 0....  ...  0.47 (std. 0.01)
# 57   {'fit_time': array([5.45679998, 5.45379925, 5....  ...  0.51 (std. 0.04)
# 100  {'fit_time': array([8.95311832, 8.79779291, 8....  ...  0.94 (std. 0.01)
# ..                                                 ...  ...               ...
# 83   {'fit_time': array([4.94725227, 4.79813504, 4....  ...    1.0 (std. 0.0)
# 4    {'fit_time': array([0.85793138, 0.79529262, 0....  ...    1.0 (std. 0.0)
# 81   {'fit_time': array([6.58462286, 6.7140131 , 6....  ...    1.0 (std. 0.0)
# 85   {'fit_time': array([0.86878991, 0.88280368, 0....  ...    1.0 (std. 0.0)
# 6    {'fit_time': array([6.11654139, 6.1371901 , 6....  ...    1.0 (std. 0.0)
#
#     test_neg_root_mean_squared_error train_neg_root_mean_squared_error  \
# 43                  0.37 (std. 0.05)                    0.0 (std. 0.0)
# 59                  0.37 (std. 0.02)                   0.37 (std. 0.0)
# 58                  0.37 (std. 0.02)                   0.37 (std. 0.0)
# 57                  0.37 (std. 0.02)                  0.37 (std. 0.01)
# 100                 0.37 (std. 0.05)                  0.17 (std. 0.02)
# ..                               ...                               ...
# 83                  0.57 (std. 0.06)                    0.0 (std. 0.0)
# 4                   0.57 (std. 0.04)                    0.0 (std. 0.0)
# 81                  0.58 (std. 0.05)                    0.0 (std. 0.0)
# 85                  0.58 (std. 0.08)                  0.04 (std. 0.02)
# 6                   0.59 (std. 0.07)                    0.0 (std. 0.0)
#
#     test_neg_mean_absolute_error train_neg_mean_absolute_error  accuracy  \
# 43              0.14 (std. 0.04)                0.0 (std. 0.0)  0.859244
# 59              0.14 (std. 0.01)               0.14 (std. 0.0)  0.859244
# 58              0.14 (std. 0.01)               0.14 (std. 0.0)  0.859244
# 57              0.14 (std. 0.01)              0.13 (std. 0.01)  0.859244
# 100             0.14 (std. 0.04)              0.03 (std. 0.01)  0.857073
# ..                           ...                           ...       ...
# 83              0.33 (std. 0.06)                0.0 (std. 0.0)  0.674268
# 4               0.33 (std. 0.04)                0.0 (std. 0.0)  0.668403
# 81              0.34 (std. 0.06)                0.0 (std. 0.0)  0.659634
# 85              0.35 (std. 0.09)                0.0 (std. 0.0)  0.651280
# 6               0.35 (std. 0.09)                0.0 (std. 0.0)  0.647815
#
#      f1_micro  f1_macro neg_root_mean_squared_error neg_mean_absolute_error
# 43   0.859244  0.588418                   -0.371365               -0.140756
# 59   0.859244  0.462126                   -0.374834               -0.140756
# 58   0.859244  0.462126                   -0.374834               -0.140756
# 57   0.859244  0.462126                   -0.374834               -0.140756
# 100  0.857073  0.638901                   -0.374465               -0.142927
# ..        ...       ...                         ...                     ...
# 83   0.674268  0.664544                   -0.567708               -0.325732
# 4    0.668403  0.653064                   -0.574694               -0.331597
# 81   0.659634  0.656603                   -0.580997               -0.340366
# 85   0.651280  0.591654                   -0.584973               -0.348720
# 6    0.647815  0.642229                   -0.589019               -0.352185
#
# [150 rows x 28 columns]

# %%
names = {'Dataset':'Dataset','dataset_variant': 'Dataset variant', 'estimator': 'Model', 'test_accuracy': 'Accuracy'}
df_table = filtered_df.filter(['Dataset','dataset_variant', 'Floor Threshold','estimator', 'test_accuracy'])
df_table = df_table.rename(columns = names)

df_table = df_table.rename(columns = names)
df_table.Model = df_table.Model.apply(lambda x: x if x.find('(') == -1 else x[:x.find('(')])
#df_table = df_table.drop_duplicates(subset=['Dataset','Model'],keep="first")
df_table = df_table.drop_duplicates(subset=['Dataset','Model','Floor Threshold'],keep="first")
display(df_table)
# Out:
#        Dataset Dataset variant Floor Threshold                       Model  \
# 43   Version 1     only_totals               6      RandomForestClassifier
# 59   Version 1     only_binary               6             RidgeClassifier
# 100  Version 2     only_totals               6  GradientBoostingClassifier
# 119  Version 2     only_binary               6      RandomForestClassifier
# 149  Version 2     only_binary               6                         SVC
# 74   Version 1     only_binary               6                         SVC
# 136  Version 2     only_totals               2                         SVC
# 133  Version 2     only_totals               6             RidgeClassifier
# 61   Version 1     only_totals               2                         SVC
# 26   Version 1     only_binary               6  GradientBoostingClassifier
# 107  Version 2     only_binary               2      RandomForestClassifier
# 120  Version 2        complete               2             RidgeClassifier
# 87   Version 2        complete               6      DecisionTreeClassifier
# 31   Version 1     only_totals               2      RandomForestClassifier
# 91   Version 2     only_totals               2  GradientBoostingClassifier
# 45   Version 1        complete               2             RidgeClassifier
# 55   Version 1     only_totals               5             RidgeClassifier
# 14   Version 1     only_binary               6      DecisionTreeClassifier
# 16   Version 1     only_totals               2  GradientBoostingClassifier
# 69   Version 1        complete               5                         SVC
# 34   Version 1     only_totals               3      RandomForestClassifier
# 76   Version 2     only_totals               2      DecisionTreeClassifier
# 0    Version 1        complete               2      DecisionTreeClassifier
# 145  Version 2     only_totals               5                         SVC
# 67   Version 1     only_totals               4                         SVC
# 19   Version 1     only_totals               3  GradientBoostingClassifier
# 139  Version 2     only_totals               3                         SVC
# 129  Version 2        complete               5             RidgeClassifier
# 108  Version 2        complete               3      RandomForestClassifier
# 94   Version 2     only_totals               3  GradientBoostingClassifier
# 40   Version 1     only_totals               5      RandomForestClassifier
# 111  Version 2        complete               4      RandomForestClassifier
# 115  Version 2     only_totals               5      RandomForestClassifier
# 65   Version 1     only_binary               3                         SVC
# 27   Version 1        complete               5  GradientBoostingClassifier
# 104  Version 2     only_binary               5  GradientBoostingClassifier
# 96   Version 2        complete               4  GradientBoostingClassifier
# 49   Version 1     only_totals               3             RidgeClassifier
# 36   Version 1        complete               4      RandomForestClassifier
# 124  Version 2     only_totals               3             RidgeClassifier
# 22   Version 1     only_totals               4  GradientBoostingClassifier
# 141  Version 2        complete               4                         SVC
# 3    Version 1        complete               3      DecisionTreeClassifier
# 51   Version 1        complete               4             RidgeClassifier
# 128  Version 2     only_binary               4             RidgeClassifier
# 11   Version 1     only_binary               5      DecisionTreeClassifier
# 8    Version 1     only_binary               4      DecisionTreeClassifier
# 80   Version 2     only_binary               3      DecisionTreeClassifier
# 84   Version 2        complete               5      DecisionTreeClassifier
# 82   Version 2     only_totals               4      DecisionTreeClassifier
#
#              Accuracy
# 43   0.86 (std. 0.04)
# 59   0.86 (std. 0.01)
# 100  0.86 (std. 0.04)
# 119  0.86 (std. 0.02)
# 149  0.85 (std. 0.01)
# 74   0.85 (std. 0.01)
# 136  0.85 (std. 0.05)
# 133  0.85 (std. 0.01)
# 61   0.85 (std. 0.04)
# 26   0.84 (std. 0.06)
# 107  0.83 (std. 0.03)
# 120  0.82 (std. 0.03)
# 87   0.82 (std. 0.04)
# 31   0.82 (std. 0.07)
# 91   0.81 (std. 0.06)
# 45   0.81 (std. 0.06)
# 55   0.81 (std. 0.08)
# 14   0.81 (std. 0.06)
# 16    0.8 (std. 0.07)
# 69    0.8 (std. 0.06)
# 34   0.79 (std. 0.08)
# 76   0.79 (std. 0.07)
# 0    0.79 (std. 0.05)
# 145  0.79 (std. 0.04)
# 67   0.78 (std. 0.08)
# 19   0.78 (std. 0.07)
# 139  0.78 (std. 0.09)
# 129  0.77 (std. 0.04)
# 108  0.77 (std. 0.06)
# 94   0.77 (std. 0.07)
# 40   0.77 (std. 0.09)
# 111  0.77 (std. 0.05)
# 115  0.77 (std. 0.06)
# 65   0.77 (std. 0.05)
# 27   0.76 (std. 0.08)
# 104  0.76 (std. 0.07)
# 96   0.76 (std. 0.06)
# 49   0.76 (std. 0.06)
# 36   0.75 (std. 0.06)
# 124  0.75 (std. 0.08)
# 22   0.74 (std. 0.06)
# 141  0.74 (std. 0.05)
# 3     0.74 (std. 0.1)
# 51   0.74 (std. 0.09)
# 128  0.73 (std. 0.06)
# 11   0.72 (std. 0.07)
# 8    0.71 (std. 0.08)
# 80    0.7 (std. 0.09)
# 84    0.7 (std. 0.06)
# 82   0.68 (std. 0.06)

# %%
filtered_table
# Out:
#    Dataset variant                       Model          Accuracy
# 11     only_binary             RidgeClassifier  0.83 (std. 0.04)
# 1      only_totals  GradientBoostingClassifier  0.83 (std. 0.04)
# 8      only_binary                         SVC  0.83 (std. 0.03)
# 13     only_totals               XGBClassifier  0.83 (std. 0.08)
# 5      only_binary      RandomForestClassifier  0.82 (std. 0.04)
# 15        complete      DecisionTreeClassifier  0.79 (std. 0.06)

# %%
filtered_table.to_latex("classification.txt")

# %%
names = {'Dataset':'Dataset','dataset_variant': 'Dataset variant', 'estimator': 'Model', 'test_neg_root_mean_squared_error': 'RMSE', 'test_r2': 'R squared', 'test_neg_mean_absolute_error' : 'MAE'}
df_table = filtered_df.filter(['Dataset','dataset_variant', 'estimator', 'test_neg_root_mean_squared_error', 'test_r2', 'test_neg_mean_absolute_error'])
df_table = df_table.rename(columns = names)
df_table.Model = df_table.Model.apply(lambda x: x if x.find('(') == -1 else x[:x.find('(')])
df_table = df_table.drop_duplicates(subset=['Dataset','Model'],keep="first")
display(df_table)
# Out:
#       Dataset Dataset variant                      Model              RMSE  \
# 19  Version 1     only_totals                        SVR  1.47 (std. 0.25)
# 13  Version 1     only_totals      RandomForestRegressor  1.51 (std. 0.23)
# 40  Version 2     only_totals                        SVR  1.52 (std. 0.14)
# 7   Version 1     only_totals  GradientBoostingRegressor   1.53 (std. 0.2)
# 28  Version 2     only_totals  GradientBoostingRegressor  1.55 (std. 0.12)
# 15  Version 1        complete                      Ridge  1.55 (std. 0.17)
# 38  Version 2     only_binary                      Ridge  1.56 (std. 0.14)
# 33  Version 2        complete      RandomForestRegressor  1.56 (std. 0.12)
# 30  Version 2        complete         LogisticRegression  1.92 (std. 0.18)
# 10  Version 1     only_totals         LogisticRegression  1.95 (std. 0.29)
# 1   Version 1     only_totals      DecisionTreeRegressor   1.99 (std. 0.3)
# 21  Version 2        complete      DecisionTreeRegressor   2.1 (std. 0.29)
# 4   Version 1     only_totals   GaussianProcessRegressor  4.79 (std. 4.94)
# 24  Version 2        complete   GaussianProcessRegressor  5.31 (std. 2.67)
#
#              R squared               MAE
# 19    0.43 (std. 0.19)   1.15 (std. 0.2)
# 13    0.41 (std. 0.19)  1.19 (std. 0.18)
# 40    0.39 (std. 0.11)   1.2 (std. 0.11)
# 7     0.39 (std. 0.16)  1.21 (std. 0.18)
# 28     0.37 (std. 0.1)  1.23 (std. 0.11)
# 15    0.38 (std. 0.13)  1.25 (std. 0.14)
# 38    0.37 (std. 0.11)  1.26 (std. 0.09)
# 33     0.37 (std. 0.1)  1.22 (std. 0.11)
# 30    0.16 (std. 0.06)  1.37 (std. 0.12)
# 10     0.23 (std. 0.2)  1.43 (std. 0.23)
# 1     0.26 (std. 0.18)  1.43 (std. 0.27)
# 21    0.29 (std. 0.21)  1.57 (std. 0.24)
# 4   11.22 (std. 28.61)  2.55 (std. 1.22)
# 24    8.21 (std. 7.95)   2.67 (std. 0.8)

# %%
latex=df_table.style.hide(axis="index").to_latex()

text_file = open("sample.txt", "w")
text_file.write(latex)
text_file.close()

# %%
names = {'dataset_variant': 'Dataset variant', 'estimator': 'Model', 'test_accuracy': 'Accuracy'}
df_table = filtered_df.filter(['dataset_variant', 'estimator', 'test_accuracy'])
df_table = df_table.rename(columns = names)

name_model = "ChainedEstimator"
filtered_table = df_table[:0]
estimators = {}
for index, row in df_table.iterrows():

    if estimators.get(row.Model) == None and name_model in row.Model:
        str_regressor = 'regressor = '
        i_regressor = row.Model.find('regressor = ')
        i_comma = row.Model.find(',')

        regressor = row.Model[i_regressor+len(str_regressor):i_comma]
        i_p = regressor.find('(')
        regressor = regressor[:i_p]
        row['Regressor'] = regressor
        
        str_clf = 'clf = '
        i_clf = row.Model.find(str_clf)
        clf = row.Model[i_clf+len(str_clf):]
        i_p = clf.find('(')
        clf = clf[:i_p]
        row['Classifier'] = clf
        print(regressor)
        print(clf)

        estimators[row.Model] = 1
        filtered_table = filtered_table.append(row)
# Out:
# RandomForestClassifier
# RidgeClassifier
# RandomForestRegressor
# SVC
# GradientBoostingRegressor
# SVC
# RandomForestRegressor
# DecisionTreeClassifier

# %%
best_results = filtered_df.iloc[0]
cv_result = best_results.cv_results.replace("\n",'')
cv_result = cv_result.replace(" ", '')
try:
    cv_dic = eval(best_results.cv_results)
except:
    i_scoring = cv_result.rfind("scoring")
    i_test = cv_result[i_scoring:].find("'test")
    cv_result = "{"+cv_result[i_scoring+i_test:]
metrics = best_results.experiment_setup['hp_optimizer']['metrics']
for metric in metrics:
    print(cv_dic[f"test_{metric}"])
    print(cv_dic[f"train_{metric}"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3748/328202535.py in <module>
#      10 metrics = best_results.experiment_setup['hp_optimizer']['metrics']
#      11 for metric in metrics:
# ---> 12     print(cv_dic[f"test_{metric}"])
#      13     print(cv_dic[f"train_{metric}"])
#
# NameError: name 'cv_dic' is not defined

# %%
best_results.experiment_setup
# Out:
# {'dataset_settings': {'dataset_variants': ['complete',
#    'only_totals',
#    'only_binary'],
#   'type_of_labels': 'floors',
#   'only_BMI': 1},
#  'task': 'Regression',
#  'pipe': {'feature_extraction': 'GroupedSVD(mask=mask)',
#   'scaler': 'MinMaxScaler()',
#   'estimator': "RandomForestRegressor(criterion = 'squared_error')"},
#  'hp_optimizer': {'type': 'RandomizeSearchCV',
#   'n_iter': 100,
#   'params': [{'feature_extraction__n_components': '[1, 2, 3]',
#     'estimator__n_estimators': '[100, 200, 250]',
#     'estimator__max_depth': '[10, 15]',
#     'estimator__max_features': "['sqrt', 'log2']"}],
#   'metrics': ['neg_root_mean_squared_error', 'r2', 'neg_mean_absolute_error'],
#   'n_split_outer_cv': 10,
#   'n_split_inner_cv': 10}}

# %%
eval(best_results.best_params)[1]
# Out:
# {'feature_extraction__n_components': 2,
#  'estimator__n_estimators': 200,
#  'estimator__max_features': 'sqrt',
#  'estimator__max_depth': 10}

# %%
filtered_df['best_params'][25]
# Out:
# "[{'feature_extraction__n_components': 2, 'estimator__n_estimators': 250, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 15}, {'feature_extraction__n_components': 2, 'estimator__n_estimators': 200, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 10}, {'feature_extraction__n_components': 2, 'estimator__n_estimators': 200, 'estimator__max_features': 'log2', 'estimator__max_depth': 10}, {'feature_extraction__n_components': 1, 'estimator__n_estimators': 200, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 15}, {'feature_extraction__n_components': 2, 'estimator__n_estimators': 250, 'estimator__max_features': 'log2', 'estimator__max_depth': 15}, {'feature_extraction__n_components': 2, 'estimator__n_estimators': 200, 'estimator__max_features': 'log2', 'estimator__max_depth': 15}, {'feature_extraction__n_components': 1, 'estimator__n_estimators': 200, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 10}, {'feature_extraction__n_components': 2, 'estimator__n_estimators': 200, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 15}, {'feature_extraction__n_components': 1, 'estimator__n_estimators': 200, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 10}, {'feature_extraction__n_components': 1, 'estimator__n_estimators': 200, 'estimator__max_features': 'log2', 'estimator__max_depth': 10}]"

# %%
filtered_df['estimator'][25]
# Out:
# "RandomForestRegressor(criterion = 'squared_error')"

# %%
filtered_df.iloc[2].best_params
# Out:
# "[{'feature_extraction__n_components': 4, 'estimator__tol': 0.0001, 'estimator__kernel': 'rbf', 'estimator__epsilon': 1e-05, 'estimator__C': 0.5}, {'feature_extraction__n_components': 4, 'estimator__tol': 0.001, 'estimator__kernel': 'rbf', 'estimator__epsilon': 0.001, 'estimator__C': 0.5}, {'feature_extraction__n_components': 5, 'estimator__tol': 0.001, 'estimator__kernel': 'rbf', 'estimator__epsilon': 0.01, 'estimator__C': 1.0}, {'feature_extraction__n_components': 4, 'estimator__tol': 0.001, 'estimator__kernel': 'rbf', 'estimator__epsilon': 0.001, 'estimator__C': 0.5}, {'feature_extraction__n_components': 5, 'estimator__tol': 0.0001, 'estimator__kernel': 'rbf', 'estimator__epsilon': 0.001, 'estimator__C': 0.5}, {'feature_extraction__n_components': 4, 'estimator__tol': 0.001, 'estimator__kernel': 'rbf', 'estimator__epsilon': 0.01, 'estimator__C': 0.5}, {'feature_extraction__n_components': 4, 'estimator__tol': 0.0001, 'estimator__kernel': 'rbf', 'estimator__epsilon': 1e-05, 'estimator__C': 1.0}, {'feature_extraction__n_components': 3, 'estimator__tol': 0.01, 'estimator__kernel': 'rbf', 'estimator__epsilon': 0.1, 'estimator__C': 0.25}, {'feature_extraction__n_components': 4, 'estimator__tol': 0.0001, 'estimator__kernel': 'rbf', 'estimator__epsilon': 1e-05, 'estimator__C': 0.5}, {'feature_extraction__n_components': 6, 'estimator__tol': 0.01, 'estimator__kernel': 'linear', 'estimator__epsilon': 0.01, 'estimator__C': 0.0625}]"
