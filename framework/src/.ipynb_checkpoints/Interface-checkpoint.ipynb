# %%
# !pip uninstall tensorflow
# !pip uninstall keras

# %%
# !pip install mord
# !pip install pandas
# !pip install cache_decorator
# !pip install scikit-learn
# !pip install scikit-fuzzy
# !pip install scikit-optimize
# !pip install xgboost
# !pip install scikeras
# Out:
# Requirement already satisfied: mord in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (0.7)
# Requirement already satisfied: pandas in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: cache_decorator in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (2.1.15)
# Requirement already satisfied: humanize>=3.4.1 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from cache_decorator) (4.6.0)
# Requirement already satisfied: compress-pickle>=2.0.1 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from cache_decorator) (2.1.0)
# Requirement already satisfied: dict-hash>=1.1.32 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from cache_decorator) (1.1.32)
# Requirement already satisfied: deflate-dict in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from cache_decorator) (1.0.11)
# Requirement already satisfied: compress-json>=1.0.4 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from cache_decorator) (1.0.8)
# Requirement already satisfied: support-developer in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from compress-json>=1.0.4->cache_decorator) (1.0.5)
# Requirement already satisfied: importlib-metadata in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from humanize>=3.4.1->cache_decorator) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from importlib-metadata->humanize>=3.4.1->cache_decorator) (4.4.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from importlib-metadata->humanize>=3.4.1->cache_decorator) (3.11.0)
# Requirement already satisfied: scikit-learn in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: scikit-fuzzy in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (0.4.2)
# Requirement already satisfied: networkx>=1.9.0 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikit-fuzzy) (2.6.3)
# Requirement already satisfied: numpy>=1.6.0 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikit-fuzzy) (1.21.5)
# Requirement already satisfied: scipy>=0.9.0 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikit-fuzzy) (1.7.3)
# Requirement already satisfied: scikit-optimize in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (0.9.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikit-optimize) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikit-optimize) (1.3.2)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikit-optimize) (1.7.3)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikit-optimize) (1.21.5)
# Requirement already satisfied: pyaml>=16.9 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikit-optimize) (23.5.8)
# Requirement already satisfied: PyYAML in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from pyaml>=16.9->scikit-optimize) (6.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikit-learn>=0.20.0->scikit-optimize) (3.1.0)
# Requirement already satisfied: xgboost in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (1.6.2)
# Requirement already satisfied: scipy in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from xgboost) (1.7.3)
# Requirement already satisfied: numpy in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scikeras in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (0.10.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikeras) (1.0.2)
# Requirement already satisfied: packaging>=0.21 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikeras) (22.0)
# Requirement already satisfied: importlib-metadata>=3 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikeras) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from importlib-metadata>=3->scikeras) (4.4.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from importlib-metadata>=3->scikeras) (3.11.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikit-learn>=1.0.0->scikeras) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikit-learn>=1.0.0->scikeras) (1.3.2)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikit-learn>=1.0.0->scikeras) (1.21.5)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\lassa\anaconda3\envs\env_3\lib\site-packages (from scikit-learn>=1.0.0->scikeras) (1.7.3)

# %%
import pandas as pd
import numpy as np
import glob
from multiprocessing import cpu_count
from experiment_tools import *
from scikeras.wrappers import KerasClassifier,KerasRegressor
working_path = "C:\\Users\\lassa\\OneDrive\\Desktop\\workspace\\VICTIMS_OF_FALL_MASTER_THESIS"

# %%
# %%time
import json


#This block run all the experiments
files = glob.glob(f"{working_path}\\input_exp\\default_models\\MLP-binary\\*.json")
for file in files:
    print(file)
    with open (file, "r") as f:
        data=f.read().replace('\n', '')
    splits = file.split("\\")
    experiment_name = splits[-1].split(".")[0]
    experiment_setup = json.loads(data)
    print(f"EXECUTION OF THE EXPERIMENT {experiment_name}")
    Experiment().experiment(working_path, "results\\default_models\\MLP-binary\\balanced-accuracy", experiment_name, experiment_setup, "victims_of_fall_V2")
# Out:
# C:\Users\lassa\OneDrive\Desktop\workspace\VICTIMS_OF_FALL_MASTER_THESIS\input_exp\default_models\MLP-binary\MLP - 2.json
# EXECUTION OF THE EXPERIMENT MLP - 2
# NUM_EXAMPLES low floors vs high floors with threshold 2: 103 // 302
# NUM_EXAMPLES low floors vs high floors with threshold 2: 103 // 302
# NUM_EXAMPLES low floors vs high floors with threshold 2: 103 // 302
# complete
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\anaconda3\envs\env_3\lib\site-packages\cache_decorator\cache.py in wrapped(*args, **kwargs)
#     613             # otherwise compute the result
#     614             start_time = time()
# --> 615             result = function(*args, **kwargs)
#     616             end_time = time()
#     617
#
# ~\OneDrive\Desktop\workspace\VICTIMS_OF_FALL_MASTER_THESIS\framework\src\experiment_tools\Experiment.py in experiment(self, working_path, result_path, experiment_name, experiment_setup, dataset_name)
#     174             pipe_steps = []
#     175             for key, value in experiment_setup["pipe"].items():
# --> 176                 pipe_steps.append((key, eval(value)))
#     177             pipe = Pipeline(pipe_steps)
#     178
#
# ~\OneDrive\Desktop\workspace\VICTIMS_OF_FALL_MASTER_THESIS\framework\src\experiment_tools\Experiment.py in <module>
#
# NameError: name 'create_model' is not defined

# %%
 #This block acquire all the results obtained
import json
files = glob.glob(f"{working_path}\\results\\default_models\\balanced-accuracy\\*.json")

filter_floor_labels = True

all_experiments_results = []
for i, file in enumerate(files):
    with open (file, "r") as f:
        
        data=f.read().replace('\n', '')
        experiment_results = json.loads(data)
        
        if type(experiment_results) == dict:
            experiment_results = [experiment_results]
            
        all_experiments_results.append(pd.DataFrame(experiment_results))

df = pd.concat(all_experiments_results)
df = df.reset_index().drop('index', axis = 1)
df["Dataset"]="Version 1"

# %%
 #This block acquire all the results obtained
import json
files = glob.glob(f"{working_path}\\results\\exp_V2\\balanced-accuracy\\*.json")
filter_floor_labels = True

all_experiments_results = []
for i, file in enumerate(files):
    with open (file, "r") as f:
        
        data=f.read().replace('\n', '')
        experiment_results = json.loads(data)
        
        if type(experiment_results) == dict:
            experiment_results = [experiment_results]
            
        all_experiments_results.append(pd.DataFrame(experiment_results))

df2 = pd.concat(all_experiments_results)
df2 = df2.reset_index().drop('index', axis = 1)
df2["Dataset"]="Version 2"

# %%
df = pd.concat([df,df2])

# %%
filter_dict = {"task" : "Regression", "cv_type" : "n_split_inner_cv"}
target_metric = "neg_root_mean_squared_error"
filtered_df = df
for k, v in filter_dict.items():
    filtered_df = filtered_df.loc[filtered_df[k] == v]

filtered_df = filtered_df.reset_index().drop('index', axis = 1)
filtered_df = filtered_df.sort_values(by = 'mean_test_score', axis=0, ascending = False, key=lambda x: x.apply(lambda y: y[target_metric]))

# %%
filter_dict = {"task" : "Classification", "cv_type" : "n_split_inner_cv"}
target_metric = "neg_root_mean_squared_error"
filtered_df = df
for k, v in filter_dict.items():
    filtered_df = filtered_df.loc[filtered_df[k] == v]

filtered_df = filtered_df.reset_index().drop('index', axis = 1)
filtered_df = filtered_df.sort_values(by = 'mean_test_score', axis=0, ascending = False, key=lambda x: x.apply(lambda y: y[target_metric]))

# %%
filter_dict = {"task" : "Classification", "cv_type" : "n_split_inner_cv"}
target_metric = "balanced_accuracy"
filtered_df = df
for k, v in filter_dict.items():
    filtered_df = filtered_df.loc[filtered_df[k] == v]

filtered_df = filtered_df.reset_index().drop('index', axis = 1)
filtered_df = filtered_df.sort_values(by = 'mean_test_score', axis=0, ascending = False, key=lambda x: x.apply(lambda y: y[target_metric]))

# %%
#USED TO ADD FLOOR THRESHOLD IN CLASSIFICATION TASK
floor_thresholds = []
for i,v in filtered_df.iterrows():
    v = v['experiment_setup']
    v = str(v).replace("'","\"")
    experiment_setup = json.loads(v)
    b = experiment_setup["dataset_settings"]['binarize']
    filtered_df.at[i,'Floor Threshold'] = str(b[0])
# Out:
# C:\Users\lassa\AppData\Local\Temp\ipykernel_5548\3513492328.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '2' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   filtered_df.at[i,'Floor Threshold'] = str(b[0])

# %%
filtered_df
# Out:
#                  experiment_name dataset_variant                 estimator  \
# 61                       SVC - 2     only_totals                     SVC()
# 67                       SVC - 4     only_totals                     SVC()
# 33   RandomForrestClassifier - 3        complete  RandomForestClassifier()
# 109  RandomForrestClassifier - 3     only_totals  RandomForestClassifier()
# 110  RandomForrestClassifier - 3     only_binary  RandomForestClassifier()
# ..                           ...             ...                       ...
# 59           RidgeClassifier - 6     only_binary         RidgeClassifier()
# 72                       SVC - 6        complete                     SVC()
# 74                       SVC - 6     only_binary                     SVC()
# 134          RidgeClassifier - 6     only_binary         RidgeClassifier()
# 73                       SVC - 6     only_totals                     SVC()
#
#                task       hp_optimizer           cv_type  \
# 61   Classification  RandomizeSearchCV  n_split_inner_cv
# 67   Classification  RandomizeSearchCV  n_split_inner_cv
# 33   Classification  RandomizeSearchCV  n_split_inner_cv
# 109  Classification  RandomizeSearchCV  n_split_inner_cv
# 110  Classification  RandomizeSearchCV  n_split_inner_cv
# ..              ...                ...               ...
# 59   Classification  RandomizeSearchCV  n_split_inner_cv
# 72   Classification  RandomizeSearchCV  n_split_inner_cv
# 74   Classification  RandomizeSearchCV  n_split_inner_cv
# 134  Classification  RandomizeSearchCV  n_split_inner_cv
# 73   Classification  RandomizeSearchCV  n_split_inner_cv
#
#                                        mean_test_score  \
# 61   {'balanced_accuracy': 0.7778055555555555, 'f1_...
# 67   {'balanced_accuracy': 0.777404970760234, 'f1_m...
# 33   {'balanced_accuracy': 0.7717669172932331, 'f1_...
# 109  {'balanced_accuracy': 0.7709692028985508, 'f1_...
# 110  {'balanced_accuracy': 0.769927536231884, 'f1_m...
# ..                                                 ...
# 59   {'balanced_accuracy': 0.49827586206896546, 'f1...
# 72   {'balanced_accuracy': 0.4966091954022989, 'f1_...
# 74   {'balanced_accuracy': 0.4966091954022989, 'f1_...
# 134  {'balanced_accuracy': 0.49563025210084033, 'f1...
# 73   {'balanced_accuracy': 0.4948850574712644, 'f1_...
#
#                                       mean_train_score  \
# 61   {'balanced_accuracy': 0.8013290362378667, 'f1_...
# 67   {'balanced_accuracy': 0.8124316111813406, 'f1_...
# 33   {'balanced_accuracy': 1.0, 'f1_micro': 1.0, 'f...
# 109  {'balanced_accuracy': 1.0, 'f1_micro': 1.0, 'f...
# 110  {'balanced_accuracy': 0.9996688741721854, 'f1_...
# ..                                                 ...
# 59   {'balanced_accuracy': 0.5143051290605231, 'f1_...
# 72   {'balanced_accuracy': 0.5508985200845666, 'f1_...
# 74   {'balanced_accuracy': 0.5381871035940804, 'f1_...
# 134  {'balanced_accuracy': 0.5226589097995299, 'f1_...
# 73   {'balanced_accuracy': 0.5229607117688513, 'f1_...
#
#                                            best_params  \
# 61   [{'feature_extraction__n_components': 2, 'feat...
# 67   [{'feature_extraction__n_components': 3, 'feat...
# 33   [{'feature_extraction__n_components': 1, 'feat...
# 109  [{'feature_extraction__n_components': 2, 'feat...
# 110  [{'feature_extraction__n_components': 1, 'feat...
# ..                                                 ...
# 59   [{'feature_extraction__n_components': 14, 'fea...
# 72   [{'feature_extraction__n_components': 6, 'feat...
# 74   [{'feature_extraction__n_components': 7, 'feat...
# 134  [{'feature_extraction__n_components': 12, 'fea...
# 73   [{'feature_extraction__n_components': 1, 'feat...
#
#                                             cv_results  \
# 61   {'fit_time': array([1.16120481, 1.09269333, 1....
# 67   {'fit_time': array([1.4592576 , 1.26422262, 1....
# 33   {'fit_time': array([85.80355597, 85.92758679, ...
# 109  {'fit_time': array([12.33890891, 12.31140447, ...
# 110  {'fit_time': array([66.31508946, 67.55437231, ...
# ..                                                 ...
# 59   {'fit_time': array([4.23174524, 4.272753  , 4....
# 72   {'fit_time': array([7.15826035, 7.31428885, 7....
# 74   {'fit_time': array([5.74451113, 5.44245863, 5....
# 134  {'fit_time': array([4.33253646, 4.0484736 , 3....
# 73   {'fit_time': array([1.12219763, 1.16270471, 1....
#
#                                       experiment_setup    Dataset  \
# 61   {'dataset_settings': {'dataset_variants': ['co...  Version 1
# 67   {'dataset_settings': {'dataset_variants': ['co...  Version 1
# 33   {'dataset_settings': {'dataset_variants': ['co...  Version 1
# 109  {'dataset_settings': {'dataset_variants': ['co...  Version 2
# 110  {'dataset_settings': {'dataset_variants': ['co...  Version 2
# ..                                                 ...        ...
# 59   {'dataset_settings': {'dataset_variants': ['co...  Version 1
# 72   {'dataset_settings': {'dataset_variants': ['co...  Version 1
# 74   {'dataset_settings': {'dataset_variants': ['co...  Version 1
# 134  {'dataset_settings': {'dataset_variants': ['co...  Version 2
# 73   {'dataset_settings': {'dataset_variants': ['co...  Version 1
#
#     Floor Threshold
# 61                2
# 67                4
# 33                3
# 109               3
# 110               3
# ..              ...
# 59                6
# 72                6
# 74                6
# 134               6
# 73                6
#
# [150 rows x 13 columns]

# %%
from numpy import array
#THIS IS USED TO EXPLODE THE DICT OF THE SCORES AS COLUMNS OF THE RESULTED FILTERED_DF
values = {}
df_table = filtered_df[:0]
estimators = {}
for index, record in filtered_df.iterrows():
    cv_result = record.cv_results

    i_scoring = cv_result.rfind("scoring")
    i_test = cv_result[i_scoring:].find("'test")
    cv_result = "{"+cv_result[i_scoring+i_test:]
    cv_result = eval(cv_result)
    
    for k, list_scores in cv_result.items():
        if values.get(k) == None:
            values[k] = []
        mean = np.round(np.mean(np.abs(list_scores)), 2)
        std = np.round(np.std(np.abs(list_scores)), 2)
        
        values[k].append(str(mean)+" (std. "+str(std)+")")
    
for k, v in values.items():
    filtered_df[k] = v

# %%
#THIS IS USED TO EXPLODE THE DICT OF THE SCORES AS COLUMNS OF THE RESULTED FILTERED_DF
values = {}
for record in filtered_df.mean_test_score:
    for k, v in record.items():
        if values.get(k) == None:
            values[k] = []
        values[k].append(v)

for k, v in values.items():
    filtered_df[k] = v

# %%
filtered_df
# Out:
#                            experiment_name dataset_variant  \
# 8       OneVsRest - RandomForestClassifier     only_binary
# 7       OneVsRest - RandomForestClassifier     only_totals
# 6       OneVsRest - RandomForestClassifier        complete
# 5   OneVsRest - GradientBoostingClassifier     only_binary
# 4   OneVsRest - GradientBoostingClassifier     only_totals
# 14                         OneVsRest - SVC     only_binary
# 12                         OneVsRest - SVC        complete
# 13                         OneVsRest - SVC     only_totals
# 3   OneVsRest - GradientBoostingClassifier        complete
# 11             OneVsRest - RidgeClassifier     only_binary
# 10             OneVsRest - RidgeClassifier     only_totals
# 9              OneVsRest - RidgeClassifier        complete
# 1       OneVsRest - DecisionTreeClassifier     only_totals
# 0       OneVsRest - DecisionTreeClassifier        complete
# 2       OneVsRest - DecisionTreeClassifier     only_binary
# 19  OneVsRest - GradientBoostingClassifier     only_totals
# 20  OneVsRest - GradientBoostingClassifier     only_binary
# 21      OneVsRest - RandomForestClassifier        complete
# 18  OneVsRest - GradientBoostingClassifier        complete
# 22      OneVsRest - RandomForestClassifier     only_totals
# 27                         OneVsRest - SVC        complete
# 23      OneVsRest - RandomForestClassifier     only_binary
# 29                         OneVsRest - SVC     only_binary
# 28                         OneVsRest - SVC     only_totals
# 24             OneVsRest - RidgeClassifier        complete
# 26             OneVsRest - RidgeClassifier     only_binary
# 25             OneVsRest - RidgeClassifier     only_totals
# 16      OneVsRest - DecisionTreeClassifier     only_totals
# 17      OneVsRest - DecisionTreeClassifier     only_binary
# 15      OneVsRest - DecisionTreeClassifier        complete
#
#                                             estimator            task  \
# 8       OneVsRestClassifier(RandomForestClassifier())  Classification
# 7       OneVsRestClassifier(RandomForestClassifier())  Classification
# 6       OneVsRestClassifier(RandomForestClassifier())  Classification
# 5   OneVsRestClassifier(GradientBoostingClassifier())  Classification
# 4   OneVsRestClassifier(GradientBoostingClassifier())  Classification
# 14                         OneVsRestClassifier(SVC())  Classification
# 12                         OneVsRestClassifier(SVC())  Classification
# 13                         OneVsRestClassifier(SVC())  Classification
# 3   OneVsRestClassifier(GradientBoostingClassifier())  Classification
# 11             OneVsRestClassifier(RidgeClassifier())  Classification
# 10             OneVsRestClassifier(RidgeClassifier())  Classification
# 9              OneVsRestClassifier(RidgeClassifier())  Classification
# 1       OneVsRestClassifier(DecisionTreeClassifier())  Classification
# 0       OneVsRestClassifier(DecisionTreeClassifier())  Classification
# 2       OneVsRestClassifier(DecisionTreeClassifier())  Classification
# 19  OneVsRestClassifier(GradientBoostingClassifier())  Classification
# 20  OneVsRestClassifier(GradientBoostingClassifier())  Classification
# 21      OneVsRestClassifier(RandomForestClassifier())  Classification
# 18  OneVsRestClassifier(GradientBoostingClassifier())  Classification
# 22      OneVsRestClassifier(RandomForestClassifier())  Classification
# 27                         OneVsRestClassifier(SVC())  Classification
# 23      OneVsRestClassifier(RandomForestClassifier())  Classification
# 29                         OneVsRestClassifier(SVC())  Classification
# 28                         OneVsRestClassifier(SVC())  Classification
# 24             OneVsRestClassifier(RidgeClassifier())  Classification
# 26             OneVsRestClassifier(RidgeClassifier())  Classification
# 25             OneVsRestClassifier(RidgeClassifier())  Classification
# 16      OneVsRestClassifier(DecisionTreeClassifier())  Classification
# 17      OneVsRestClassifier(DecisionTreeClassifier())  Classification
# 15      OneVsRestClassifier(DecisionTreeClassifier())  Classification
#
#          hp_optimizer           cv_type  \
# 8   RandomizeSearchCV  n_split_inner_cv
# 7   RandomizeSearchCV  n_split_inner_cv
# 6   RandomizeSearchCV  n_split_inner_cv
# 5   RandomizeSearchCV  n_split_inner_cv
# 4   RandomizeSearchCV  n_split_inner_cv
# 14  RandomizeSearchCV  n_split_inner_cv
# 12  RandomizeSearchCV  n_split_inner_cv
# 13  RandomizeSearchCV  n_split_inner_cv
# 3   RandomizeSearchCV  n_split_inner_cv
# 11  RandomizeSearchCV  n_split_inner_cv
# 10  RandomizeSearchCV  n_split_inner_cv
# 9   RandomizeSearchCV  n_split_inner_cv
# 1   RandomizeSearchCV  n_split_inner_cv
# 0   RandomizeSearchCV  n_split_inner_cv
# 2   RandomizeSearchCV  n_split_inner_cv
# 19  RandomizeSearchCV  n_split_inner_cv
# 20  RandomizeSearchCV  n_split_inner_cv
# 21  RandomizeSearchCV  n_split_inner_cv
# 18  RandomizeSearchCV  n_split_inner_cv
# 22  RandomizeSearchCV  n_split_inner_cv
# 27  RandomizeSearchCV  n_split_inner_cv
# 23  RandomizeSearchCV  n_split_inner_cv
# 29  RandomizeSearchCV  n_split_inner_cv
# 28  RandomizeSearchCV  n_split_inner_cv
# 24  RandomizeSearchCV  n_split_inner_cv
# 26  RandomizeSearchCV  n_split_inner_cv
# 25  RandomizeSearchCV  n_split_inner_cv
# 16  RandomizeSearchCV  n_split_inner_cv
# 17  RandomizeSearchCV  n_split_inner_cv
# 15  RandomizeSearchCV  n_split_inner_cv
#
#                                       mean_test_score  \
# 8   {'accuracy': 0.36647058823529416, 'f1_micro': ...
# 7   {'accuracy': 0.3691596638655462, 'f1_micro': 0...
# 6   {'accuracy': 0.4046218487394958, 'f1_micro': 0...
# 5   {'accuracy': 0.35764705882352943, 'f1_micro': ...
# 4   {'accuracy': 0.34907563025210087, 'f1_micro': ...
# 14  {'accuracy': 0.36050420168067226, 'f1_micro': ...
# 12  {'accuracy': 0.32563025210084034, 'f1_micro': ...
# 13  {'accuracy': 0.32260504201680673, 'f1_micro': ...
# 3   {'accuracy': 0.34310924369747897, 'f1_micro': ...
# 11  {'accuracy': 0.2959663865546219, 'f1_micro': 0...
# 10  {'accuracy': 0.2959663865546219, 'f1_micro': 0...
# 9   {'accuracy': 0.2753781512605042, 'f1_micro': 0...
# 1   {'accuracy': 0.3108403361344538, 'f1_micro': 0...
# 0   {'accuracy': 0.2786554621848739, 'f1_micro': 0...
# 2   {'accuracy': 0.29067226890756304, 'f1_micro': ...
# 19  {'accuracy': 0.3282926829268292, 'f1_micro': 0...
# 20  {'accuracy': 0.3135365853658537, 'f1_micro': 0...
# 21  {'accuracy': 0.3156707317073171, 'f1_micro': 0...
# 18  {'accuracy': 0.31353658536585366, 'f1_micro': ...
# 22  {'accuracy': 0.3259146341463415, 'f1_micro': 0...
# 27  {'accuracy': 0.31097560975609756, 'f1_micro': ...
# 23  {'accuracy': 0.33829268292682924, 'f1_micro': ...
# 29  {'accuracy': 0.30091463414634145, 'f1_micro': ...
# 28  {'accuracy': 0.34298780487804875, 'f1_micro': ...
# 24  {'accuracy': 0.2568902439024391, 'f1_micro': 0...
# 26  {'accuracy': 0.27402439024390246, 'f1_micro': ...
# 25  {'accuracy': 0.2714024390243902, 'f1_micro': 0...
# 16  {'accuracy': 0.2811585365853658, 'f1_micro': 0...
# 17  {'accuracy': 0.2734756097560976, 'f1_micro': 0...
# 15  {'accuracy': 0.29609756097560974, 'f1_micro': ...
#
#                                      mean_train_score  \
# 8   {'accuracy': 1.0, 'f1_micro': 1.0, 'f1_macro':...
# 7   {'accuracy': 0.9973930723212195, 'f1_micro': 0...
# 6   {'accuracy': 1.0, 'f1_micro': 1.0, 'f1_macro':...
# 5   {'accuracy': 0.9928306827617039, 'f1_micro': 0...
# 4   {'accuracy': 0.9889240169466266, 'f1_micro': 0...
# 14  {'accuracy': 0.8162334206212345, 'f1_micro': 0...
# 12  {'accuracy': 0.8100136254284559, 'f1_micro': 0...
# 13  {'accuracy': 0.6419109663409339, 'f1_micro': 0...
# 3   {'accuracy': 0.994460411743416, 'f1_micro': 0....
# 11  {'accuracy': 0.3994517894019714, 'f1_micro': 0...
# 10  {'accuracy': 0.3287730727470141, 'f1_micro': 0...
# 9   {'accuracy': 0.3991271209895467, 'f1_micro': 0...
# 1   {'accuracy': 0.9973930723212195, 'f1_micro': 0...
# 0   {'accuracy': 1.0, 'f1_micro': 1.0, 'f1_macro':...
# 2   {'accuracy': 1.0, 'f1_micro': 1.0, 'f1_macro':...
# 19  {'accuracy': 0.975030106879422, 'f1_micro': 0....
# 20  {'accuracy': 0.9851821466205027, 'f1_micro': 0...
# 21  {'accuracy': 1.0, 'f1_micro': 1.0, 'f1_macro':...
# 18  {'accuracy': 0.979969893120578, 'f1_micro': 0....
# 22  {'accuracy': 0.9978059611621257, 'f1_micro': 0...
# 27  {'accuracy': 0.7865798584976668, 'f1_micro': 0...
# 23  {'accuracy': 1.0, 'f1_micro': 1.0, 'f1_macro':...
# 29  {'accuracy': 0.7748073159716996, 'f1_micro': 0...
# 28  {'accuracy': 0.622788649706458, 'f1_micro': 0....
# 24  {'accuracy': 0.370657082643384, 'f1_micro': 0....
# 26  {'accuracy': 0.35884314315821164, 'f1_micro': ...
# 25  {'accuracy': 0.32044257112750263, 'f1_micro': ...
# 16  {'accuracy': 0.9978059611621257, 'f1_micro': 0...
# 17  {'accuracy': 1.0, 'f1_micro': 1.0, 'f1_macro':...
# 15  {'accuracy': 1.0, 'f1_micro': 1.0, 'f1_macro':...
#
#                                           best_params  \
# 8   [{'feature_extraction__n_components': 1, 'feat...
# 7   [{'feature_extraction__n_components': 3, 'feat...
# 6   [{'feature_extraction__n_components': 3, 'feat...
# 5   [{'feature_extraction__n_components': 4, 'feat...
# 4   [{'feature_extraction__n_components': 2, 'feat...
# 14  [{'feature_extraction__n_components': 8, 'feat...
# 12  [{'feature_extraction__n_components': 4, 'feat...
# 13  [{'feature_extraction__n_components': 3, 'feat...
# 3   [{'feature_extraction__n_components': 2, 'feat...
# 11  [{'feature_extraction__n_components': 1, 'feat...
# 10  [{'feature_extraction__n_components': 3, 'feat...
# 9   [{'feature_extraction__n_components': 2, 'feat...
# 1   [{'feature_extraction__n_components': 3, 'feat...
# 0   [{'feature_extraction__n_components': 1, 'feat...
# 2   [{'feature_extraction__n_components': 4, 'feat...
# 19  [{'feature_extraction__n_components': 2, 'feat...
# 20  [{'feature_extraction__n_components': 2, 'feat...
# 21  [{'feature_extraction__n_components': 1, 'feat...
# 18  [{'feature_extraction__n_components': 3, 'feat...
# 22  [{'feature_extraction__n_components': 2, 'feat...
# 27  [{'feature_extraction__n_components': 7, 'feat...
# 23  [{'feature_extraction__n_components': 2, 'feat...
# 29  [{'feature_extraction__n_components': 7, 'feat...
# 28  [{'feature_extraction__n_components': 3, 'feat...
# 24  [{'feature_extraction__n_components': 9, 'feat...
# 26  [{'feature_extraction__n_components': 1, 'feat...
# 25  [{'feature_extraction__n_components': 1, 'feat...
# 16  [{'feature_extraction__n_components': 2, 'feat...
# 17  [{'feature_extraction__n_components': 2, 'feat...
# 15  [{'feature_extraction__n_components': 2, 'feat...
#
#                                            cv_results  ...    train_f1_macro  \
# 8   {'fit_time': array([542.09363866, 642.3958056 ...  ...    1.0 (std. 0.0)
# 7   {'fit_time': array([ 94.11274242,  94.86887503...  ...    1.0 (std. 0.0)
# 6   {'fit_time': array([589.8425498 , 590.97975087...  ...    1.0 (std. 0.0)
# 5   {'fit_time': array([889.5190661 , 610.97350311...  ...   0.99 (std. 0.0)
# 4   {'fit_time': array([57.10155678, 57.52613163, ...  ...   0.99 (std. 0.0)
# 14  {'fit_time': array([25.30145669, 25.4664855 , ...  ...  0.82 (std. 0.05)
# 12  {'fit_time': array([47.47086358, 35.3397274 , ...  ...  0.81 (std. 0.06)
# 13  {'fit_time': array([4.89136267, 4.80534649, 4....  ...  0.64 (std. 0.04)
# 3   {'fit_time': array([736.50822711, 751.28332949...  ...   0.99 (std. 0.0)
# 11  {'fit_time': array([10.45234156,  9.89324355, ...  ...  0.37 (std. 0.05)
# 10  {'fit_time': array([1.71230125, 1.70479989, 1....  ...  0.27 (std. 0.01)
# 9   {'fit_time': array([12.62872434, 12.4391911 , ...  ...  0.36 (std. 0.07)
# 1   {'fit_time': array([1.61228371, 1.60328174, 1....  ...    1.0 (std. 0.0)
# 0   {'fit_time': array([20.7486558 , 21.28374887, ...  ...    1.0 (std. 0.0)
# 2   {'fit_time': array([14.36152983, 14.87312078, ...  ...    1.0 (std. 0.0)
# 19  {'fit_time': array([61.61394262, 61.90697432, ...  ...  0.98 (std. 0.01)
# 20  {'fit_time': array([826.48077083, 851.08451033...  ...   0.99 (std. 0.0)
# 21  {'fit_time': array([616.37900066, 611.42050552...  ...    1.0 (std. 0.0)
# 18  {'fit_time': array([821.46654367, 827.11484408...  ...  0.98 (std. 0.01)
# 22  {'fit_time': array([83.43576264, 82.97642231, ...  ...    1.0 (std. 0.0)
# 27  {'fit_time': array([32.45167971, 33.83710074, ...  ...  0.79 (std. 0.06)
# 23  {'fit_time': array([470.06404996, 466.64374065...  ...    1.0 (std. 0.0)
# 29  {'fit_time': array([25.28332019, 24.83772302, ...  ...  0.77 (std. 0.07)
# 28  {'fit_time': array([4.8085258 , 4.93682003, 4....  ...  0.62 (std. 0.04)
# 24  {'fit_time': array([10.59509373, 10.51691318, ...  ...  0.34 (std. 0.04)
# 26  {'fit_time': array([8.24829745, 8.29389429, 8....  ...  0.33 (std. 0.04)
# 25  {'fit_time': array([1.41624784, 1.37216735, 1....  ...  0.27 (std. 0.01)
# 16  {'fit_time': array([1.64378905, 1.67529511, 1....  ...    1.0 (std. 0.0)
# 17  {'fit_time': array([15.96281195, 15.13266611, ...  ...    1.0 (std. 0.0)
# 15  {'fit_time': array([21.57529998, 21.67181826, ...  ...    1.0 (std. 0.0)
#
#    test_neg_root_mean_squared_error train_neg_root_mean_squared_error  \
# 8                   1.76 (std. 0.3)                    0.0 (std. 0.0)
# 7                  1.78 (std. 0.31)                  0.05 (std. 0.02)
# 6                   1.8 (std. 0.27)                    0.0 (std. 0.0)
# 5                   1.85 (std. 0.2)                  0.18 (std. 0.13)
# 4                  1.86 (std. 0.24)                  0.19 (std. 0.05)
# 14                  1.9 (std. 0.17)                  1.12 (std. 0.13)
# 12                 1.92 (std. 0.19)                  1.09 (std. 0.19)
# 13                 1.92 (std. 0.29)                  1.47 (std. 0.08)
# 3                  1.96 (std. 0.27)                  0.15 (std. 0.14)
# 11                 2.04 (std. 0.26)                  1.92 (std. 0.07)
# 10                 2.06 (std. 0.25)                  2.03 (std. 0.03)
# 9                  2.08 (std. 0.25)                   1.92 (std. 0.1)
# 1                  2.35 (std. 0.17)                  0.05 (std. 0.02)
# 0                  2.57 (std. 0.28)                    0.0 (std. 0.0)
# 2                  2.62 (std. 0.23)                    0.0 (std. 0.0)
# 19                  5.4 (std. 0.44)                  1.14 (std. 0.23)
# 20                 5.78 (std. 0.41)                  0.96 (std. 0.27)
# 21                 5.79 (std. 0.78)                    0.0 (std. 0.0)
# 18                 5.82 (std. 0.58)                  1.11 (std. 0.27)
# 22                 5.84 (std. 0.75)                  0.13 (std. 0.06)
# 27                   5.9 (std. 0.5)                  3.32 (std. 0.48)
# 23                 5.98 (std. 0.88)                    0.0 (std. 0.0)
# 29                 6.09 (std. 0.75)                   3.5 (std. 0.53)
# 28                  6.17 (std. 0.5)                  4.44 (std. 0.31)
# 24                 6.26 (std. 0.75)                  6.09 (std. 0.27)
# 26                 6.42 (std. 0.81)                  6.16 (std. 0.23)
# 25                 6.64 (std. 0.73)                  6.32 (std. 0.08)
# 16                 7.12 (std. 0.87)                  0.13 (std. 0.06)
# 17                 7.21 (std. 0.55)                    0.0 (std. 0.0)
# 15                 7.23 (std. 0.76)                    0.0 (std. 0.0)
#
#    test_neg_mean_absolute_error train_neg_mean_absolute_error  accuracy  \
# 8              1.21 (std. 0.25)                0.0 (std. 0.0)  0.366471
# 7               1.23 (std. 0.3)                0.0 (std. 0.0)  0.369160
# 6               1.2 (std. 0.23)                0.0 (std. 0.0)  0.404622
# 5               1.28 (std. 0.2)              0.01 (std. 0.01)  0.357647
# 4               1.3 (std. 0.24)              0.02 (std. 0.01)  0.349076
# 14             1.32 (std. 0.17)              0.42 (std. 0.11)  0.360504
# 12             1.36 (std. 0.15)              0.41 (std. 0.14)  0.325630
# 13             1.38 (std. 0.27)              0.75 (std. 0.09)  0.322605
# 3              1.38 (std. 0.25)              0.01 (std. 0.01)  0.343109
# 11             1.48 (std. 0.23)              1.29 (std. 0.09)  0.295966
# 10              1.5 (std. 0.18)              1.43 (std. 0.03)  0.295966
# 9              1.55 (std. 0.25)               1.3 (std. 0.12)  0.275378
# 1              1.67 (std. 0.15)                0.0 (std. 0.0)  0.310840
# 0              1.88 (std. 0.27)                0.0 (std. 0.0)  0.278655
# 2                1.9 (std. 0.3)                0.0 (std. 0.0)  0.290672
# 19             3.89 (std. 0.44)              0.16 (std. 0.05)  0.328293
# 20             4.19 (std. 0.49)              0.11 (std. 0.04)  0.313537
# 21              4.2 (std. 0.67)                0.0 (std. 0.0)  0.315671
# 18              4.2 (std. 0.44)              0.14 (std. 0.05)  0.313537
# 22             4.19 (std. 0.63)               0.01 (std. 0.0)  0.325915
# 27             4.27 (std. 0.45)              1.34 (std. 0.39)  0.310976
# 23             4.25 (std. 0.76)                0.0 (std. 0.0)  0.338293
# 29             4.44 (std. 0.57)              1.45 (std. 0.45)  0.300915
# 28             4.28 (std. 0.43)              2.35 (std. 0.28)  0.342988
# 24             4.68 (std. 0.55)              4.17 (std. 0.28)  0.256890
# 26             4.78 (std. 0.62)              4.27 (std. 0.23)  0.274024
# 25             4.93 (std. 0.57)               4.5 (std. 0.08)  0.271402
# 16             5.23 (std. 0.75)               0.01 (std. 0.0)  0.281159
# 17             5.31 (std. 0.64)                0.0 (std. 0.0)  0.273476
# 15             5.29 (std. 0.72)                0.0 (std. 0.0)  0.296098
#
#     f1_micro  f1_macro neg_root_mean_squared_error neg_mean_absolute_error
# 8   0.366471  0.357348                   -1.760225               -1.213529
# 7   0.369160  0.355824                   -1.783885               -1.232353
# 6   0.404622  0.390854                   -1.795603               -1.202269
# 5   0.357647  0.351475                   -1.848182               -1.284958
# 4   0.349076  0.340013                   -1.859567               -1.304958
# 14  0.360504  0.345140                   -1.904484               -1.322185
# 12  0.325630  0.305727                   -1.919268               -1.362857
# 13  0.322605  0.297572                   -1.922875               -1.378571
# 3   0.343109  0.339186                   -1.961510               -1.376134
# 11  0.295966  0.266244                   -2.043217               -1.475798
# 10  0.295966  0.237046                   -2.055352               -1.502353
# 9   0.275378  0.239956                   -2.083942               -1.549160
# 1   0.310840  0.295550                   -2.353881               -1.667983
# 0   0.278655  0.270969                   -2.571692               -1.876387
# 2   0.290672  0.290447                   -2.618180               -1.902185
# 19  0.328293  0.317394                   -5.397657               -3.890488
# 20  0.313537  0.298662                   -5.780325               -4.194512
# 21  0.315671  0.302876                   -5.790692               -4.203476
# 18  0.313537  0.296647                   -5.817942               -4.199085
# 22  0.325915  0.316574                   -5.844953               -4.187561
# 27  0.310976  0.295164                   -5.896552               -4.269146
# 23  0.338293  0.332278                   -5.982186               -4.251220
# 29  0.300915  0.278112                   -6.092554               -4.441098
# 28  0.342988  0.330345                   -6.168583               -4.278110
# 24  0.256890  0.230778                   -6.263200               -4.682378
# 26  0.274024  0.243988                   -6.421973               -4.778963
# 25  0.271402  0.225605                   -6.635611               -4.928049
# 16  0.281159  0.265107                   -7.118230               -5.228049
# 17  0.273476  0.253203                   -7.205378               -5.308171
# 15  0.296098  0.284145                   -7.234907               -5.285122
#
# [30 rows x 27 columns]

# %%
names = {'Dataset':'Dataset','dataset_variant': 'Dataset variant', 'estimator': 'Model', 'test_neg_root_mean_squared_error': 'RMSE', 'test_neg_mean_absolute_error' : 'MAE'}
df_table = filtered_df.filter(['Dataset','dataset_variant', 'estimator', 'test_neg_root_mean_squared_error', 'test_neg_mean_absolute_error'])
df_table = df_table.rename(columns = names)

df_table = df_table.rename(columns = names)
df_table.Model = df_table.Model.apply(lambda x: x if x.find('(') == -1 else x[x.find('(')+1:])
df_table.Model = df_table.Model.apply(lambda x: x if x.find('(') == -1 else x[:x.find('(')])

df_table = df_table.drop_duplicates(subset=['Dataset','Model'],keep="first")
display(df_table)
# Out:
#       Dataset Dataset variant                       Model              RMSE  \
# 8   Version 1     only_binary      RandomForestClassifier   1.76 (std. 0.3)
# 5   Version 1     only_binary  GradientBoostingClassifier   1.85 (std. 0.2)
# 14  Version 1     only_binary                         SVC   1.9 (std. 0.17)
# 11  Version 1     only_binary             RidgeClassifier  2.04 (std. 0.26)
# 1   Version 1     only_totals      DecisionTreeClassifier  2.35 (std. 0.17)
# 19  Version 2     only_totals  GradientBoostingClassifier   5.4 (std. 0.44)
# 21  Version 2        complete      RandomForestClassifier  5.79 (std. 0.78)
# 27  Version 2        complete                         SVC    5.9 (std. 0.5)
# 24  Version 2        complete             RidgeClassifier  6.26 (std. 0.75)
# 16  Version 2     only_totals      DecisionTreeClassifier  7.12 (std. 0.87)
#
#                  MAE
# 8   1.21 (std. 0.25)
# 5    1.28 (std. 0.2)
# 14  1.32 (std. 0.17)
# 11  1.48 (std. 0.23)
# 1   1.67 (std. 0.15)
# 19  3.89 (std. 0.44)
# 21   4.2 (std. 0.67)
# 27  4.27 (std. 0.45)
# 24  4.68 (std. 0.55)
# 16  5.23 (std. 0.75)

# %%
filtered_table
# Out:
#    Dataset variant                       Model          Accuracy
# 11     only_binary             RidgeClassifier  0.83 (std. 0.04)
# 1      only_totals  GradientBoostingClassifier  0.83 (std. 0.04)
# 8      only_binary                         SVC  0.83 (std. 0.03)
# 13     only_totals               XGBClassifier  0.83 (std. 0.08)
# 5      only_binary      RandomForestClassifier  0.82 (std. 0.04)
# 15        complete      DecisionTreeClassifier  0.79 (std. 0.06)

# %%
filtered_table.to_latex("classification.txt")

# %%
names = {'Dataset':'Dataset','dataset_variant': 'Dataset variant', 'estimator': 'Model', 'test_balanced_accuracy': 'Balanced Accuracy'}
df_table = filtered_df.filter(['Dataset','dataset_variant', 'Floor Threshold','estimator', 'test_balanced_accuracy'])
df_table = df_table.rename(columns = names)

df_table = df_table.rename(columns = names)
df_table.Model = df_table.Model.apply(lambda x: x if x.find('(') == -1 else x[:x.find('(')])
#df_table = df_table.drop_duplicates(subset=['Dataset','Model'],keep="first")
df_table = df_table.drop_duplicates(subset=['Dataset','Model','Floor Threshold'],keep="first")
display(df_table)
# Out:
#        Dataset Dataset variant Floor Threshold                       Model  \
# 61   Version 1     only_totals               2                         SVC
# 67   Version 1     only_totals               4                         SVC
# 33   Version 1        complete               3      RandomForestClassifier
# 109  Version 2     only_totals               3      RandomForestClassifier
# 136  Version 2     only_totals               2                         SVC
# 105  Version 2        complete               2      RandomForestClassifier
# 94   Version 2     only_totals               3  GradientBoostingClassifier
# 138  Version 2        complete               3                         SVC
# 19   Version 1     only_totals               3  GradientBoostingClassifier
# 63   Version 1        complete               3                         SVC
# 96   Version 2        complete               4  GradientBoostingClassifier
# 48   Version 1        complete               3             RidgeClassifier
# 141  Version 2        complete               4                         SVC
# 111  Version 2        complete               4      RandomForestClassifier
# 21   Version 1        complete               4  GradientBoostingClassifier
# 30   Version 1        complete               2      RandomForestClassifier
# 76   Version 2     only_totals               2      DecisionTreeClassifier
# 124  Version 2     only_totals               3             RidgeClassifier
# 51   Version 1        complete               4             RidgeClassifier
# 38   Version 1     only_binary               4      RandomForestClassifier
# 92   Version 2     only_binary               2  GradientBoostingClassifier
# 0    Version 1        complete               2      DecisionTreeClassifier
# 55   Version 1     only_totals               5             RidgeClassifier
# 16   Version 1     only_totals               2  GradientBoostingClassifier
# 69   Version 1        complete               5                         SVC
# 128  Version 2     only_binary               4             RidgeClassifier
# 45   Version 1        complete               2             RidgeClassifier
# 3    Version 1        complete               3      DecisionTreeClassifier
# 120  Version 2        complete               2             RidgeClassifier
# 79   Version 2     only_totals               3      DecisionTreeClassifier
# 7    Version 1     only_totals               4      DecisionTreeClassifier
# 145  Version 2     only_totals               5                         SVC
# 28   Version 1     only_totals               5  GradientBoostingClassifier
# 82   Version 2     only_totals               4      DecisionTreeClassifier
# 40   Version 1     only_totals               5      RandomForestClassifier
# 115  Version 2     only_totals               5      RandomForestClassifier
# 131  Version 2     only_binary               5             RidgeClassifier
# 104  Version 2     only_binary               5  GradientBoostingClassifier
# 10   Version 1     only_totals               5      DecisionTreeClassifier
# 13   Version 1     only_totals               6      DecisionTreeClassifier
# 86   Version 2     only_binary               5      DecisionTreeClassifier
# 44   Version 1     only_binary               6      RandomForestClassifier
# 89   Version 2     only_binary               6      DecisionTreeClassifier
# 100  Version 2     only_totals               6  GradientBoostingClassifier
# 117  Version 2        complete               6      RandomForestClassifier
# 25   Version 1     only_totals               6  GradientBoostingClassifier
# 147  Version 2        complete               6                         SVC
# 133  Version 2     only_totals               6             RidgeClassifier
# 57   Version 1        complete               6             RidgeClassifier
# 72   Version 1        complete               6                         SVC
#
#     Balanced Accuracy
# 61   0.78 (std. 0.06)
# 67   0.78 (std. 0.08)
# 33   0.77 (std. 0.07)
# 109  0.77 (std. 0.08)
# 136  0.77 (std. 0.08)
# 105  0.77 (std. 0.09)
# 94   0.76 (std. 0.07)
# 138  0.76 (std. 0.09)
# 19   0.76 (std. 0.08)
# 63   0.75 (std. 0.06)
# 96   0.75 (std. 0.07)
# 48   0.75 (std. 0.07)
# 141  0.74 (std. 0.04)
# 111  0.74 (std. 0.05)
# 21   0.74 (std. 0.08)
# 30    0.74 (std. 0.1)
# 76   0.74 (std. 0.11)
# 124  0.74 (std. 0.09)
# 51   0.74 (std. 0.08)
# 38   0.73 (std. 0.07)
# 92   0.73 (std. 0.08)
# 0    0.73 (std. 0.09)
# 55   0.73 (std. 0.08)
# 16    0.72 (std. 0.1)
# 69   0.72 (std. 0.09)
# 128  0.72 (std. 0.07)
# 45   0.71 (std. 0.08)
# 3    0.71 (std. 0.09)
# 120   0.7 (std. 0.05)
# 79   0.69 (std. 0.05)
# 7    0.69 (std. 0.08)
# 145  0.69 (std. 0.07)
# 28   0.69 (std. 0.09)
# 82   0.68 (std. 0.07)
# 40    0.68 (std. 0.1)
# 115  0.68 (std. 0.07)
# 131  0.68 (std. 0.07)
# 104  0.67 (std. 0.08)
# 10   0.67 (std. 0.07)
# 13   0.64 (std. 0.15)
# 86   0.64 (std. 0.09)
# 44   0.64 (std. 0.09)
# 89   0.63 (std. 0.08)
# 100  0.62 (std. 0.07)
# 117  0.62 (std. 0.07)
# 25   0.61 (std. 0.09)
# 147  0.53 (std. 0.06)
# 133  0.51 (std. 0.02)
# 57   0.51 (std. 0.03)
# 72    0.5 (std. 0.01)

# %%
names = {'Dataset':'Dataset','dataset_variant': 'Dataset variant', 'estimator': 'Model', 'test_neg_root_mean_squared_error': 'RMSE', 'test_r2': 'R squared', 'test_neg_mean_absolute_error' : 'MAE'}
df_table = filtered_df.filter(['Dataset','dataset_variant', 'estimator', 'test_neg_root_mean_squared_error', 'test_r2', 'test_neg_mean_absolute_error'])
df_table = df_table.rename(columns = names)
df_table.Model = df_table.Model.apply(lambda x: x if x.find('(') == -1 else x[:x.find('(')])
df_table = df_table.drop_duplicates(subset=['Dataset','Model'],keep="first")
display(df_table)
# Out:
#       Dataset Dataset variant                      Model              RMSE  \
# 19  Version 1     only_totals                        SVR  1.47 (std. 0.25)
# 13  Version 1     only_totals      RandomForestRegressor  1.51 (std. 0.23)
# 40  Version 2     only_totals                        SVR  1.52 (std. 0.14)
# 7   Version 1     only_totals  GradientBoostingRegressor   1.53 (std. 0.2)
# 28  Version 2     only_totals  GradientBoostingRegressor  1.55 (std. 0.12)
# 15  Version 1        complete                      Ridge  1.55 (std. 0.17)
# 38  Version 2     only_binary                      Ridge  1.56 (std. 0.14)
# 33  Version 2        complete      RandomForestRegressor  1.56 (std. 0.12)
# 30  Version 2        complete         LogisticRegression  1.92 (std. 0.18)
# 10  Version 1     only_totals         LogisticRegression  1.95 (std. 0.29)
# 1   Version 1     only_totals      DecisionTreeRegressor   1.99 (std. 0.3)
# 21  Version 2        complete      DecisionTreeRegressor   2.1 (std. 0.29)
# 4   Version 1     only_totals   GaussianProcessRegressor  4.79 (std. 4.94)
# 24  Version 2        complete   GaussianProcessRegressor  5.31 (std. 2.67)
#
#              R squared               MAE
# 19    0.43 (std. 0.19)   1.15 (std. 0.2)
# 13    0.41 (std. 0.19)  1.19 (std. 0.18)
# 40    0.39 (std. 0.11)   1.2 (std. 0.11)
# 7     0.39 (std. 0.16)  1.21 (std. 0.18)
# 28     0.37 (std. 0.1)  1.23 (std. 0.11)
# 15    0.38 (std. 0.13)  1.25 (std. 0.14)
# 38    0.37 (std. 0.11)  1.26 (std. 0.09)
# 33     0.37 (std. 0.1)  1.22 (std. 0.11)
# 30    0.16 (std. 0.06)  1.37 (std. 0.12)
# 10     0.23 (std. 0.2)  1.43 (std. 0.23)
# 1     0.26 (std. 0.18)  1.43 (std. 0.27)
# 21    0.29 (std. 0.21)  1.57 (std. 0.24)
# 4   11.22 (std. 28.61)  2.55 (std. 1.22)
# 24    8.21 (std. 7.95)   2.67 (std. 0.8)

# %%
latex=df_table.style.hide(axis="index").to_latex()

text_file = open("sample.txt", "w")
text_file.write(latex)
text_file.close()

# %%
names = {'dataset_variant': 'Dataset variant', 'estimator': 'Model', 'test_accuracy': 'Accuracy'}
df_table = filtered_df.filter(['dataset_variant', 'estimator', 'test_accuracy'])
df_table = df_table.rename(columns = names)

name_model = "ChainedEstimator"
filtered_table = df_table[:0]
estimators = {}
for index, row in df_table.iterrows():

    if estimators.get(row.Model) == None and name_model in row.Model:
        str_regressor = 'regressor = '
        i_regressor = row.Model.find('regressor = ')
        i_comma = row.Model.find(',')

        regressor = row.Model[i_regressor+len(str_regressor):i_comma]
        i_p = regressor.find('(')
        regressor = regressor[:i_p]
        row['Regressor'] = regressor
        
        str_clf = 'clf = '
        i_clf = row.Model.find(str_clf)
        clf = row.Model[i_clf+len(str_clf):]
        i_p = clf.find('(')
        clf = clf[:i_p]
        row['Classifier'] = clf
        print(regressor)
        print(clf)

        estimators[row.Model] = 1
        filtered_table = filtered_table.append(row)
# Out:
# RandomForestClassifier
# RidgeClassifier
# RandomForestRegressor
# SVC
# GradientBoostingRegressor
# SVC
# RandomForestRegressor
# DecisionTreeClassifier

# %%
best_results = filtered_df.iloc[0]
cv_result = best_results.cv_results.replace("\n",'')
cv_result = cv_result.replace(" ", '')
try:
    cv_dic = eval(best_results.cv_results)
except:
    i_scoring = cv_result.rfind("scoring")
    i_test = cv_result[i_scoring:].find("'test")
    cv_result = "{"+cv_result[i_scoring+i_test:]
metrics = best_results.experiment_setup['hp_optimizer']['metrics']
for metric in metrics:
    print(cv_dic[f"test_{metric}"])
    print(cv_dic[f"train_{metric}"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3748/328202535.py in <module>
#      10 metrics = best_results.experiment_setup['hp_optimizer']['metrics']
#      11 for metric in metrics:
# ---> 12     print(cv_dic[f"test_{metric}"])
#      13     print(cv_dic[f"train_{metric}"])
#
# NameError: name 'cv_dic' is not defined

# %%
best_results.experiment_setup
# Out:
# {'dataset_settings': {'dataset_variants': ['complete',
#    'only_totals',
#    'only_binary'],
#   'type_of_labels': 'floors',
#   'only_BMI': 1},
#  'task': 'Regression',
#  'pipe': {'feature_extraction': 'GroupedSVD(mask=mask)',
#   'scaler': 'MinMaxScaler()',
#   'estimator': "RandomForestRegressor(criterion = 'squared_error')"},
#  'hp_optimizer': {'type': 'RandomizeSearchCV',
#   'n_iter': 100,
#   'params': [{'feature_extraction__n_components': '[1, 2, 3]',
#     'estimator__n_estimators': '[100, 200, 250]',
#     'estimator__max_depth': '[10, 15]',
#     'estimator__max_features': "['sqrt', 'log2']"}],
#   'metrics': ['neg_root_mean_squared_error', 'r2', 'neg_mean_absolute_error'],
#   'n_split_outer_cv': 10,
#   'n_split_inner_cv': 10}}

# %%
eval(best_results.best_params)[1]
# Out:
# {'feature_extraction__n_components': 2,
#  'estimator__n_estimators': 200,
#  'estimator__max_features': 'sqrt',
#  'estimator__max_depth': 10}

# %%
filtered_df['best_params'][25]
# Out:
# "[{'feature_extraction__n_components': 2, 'estimator__n_estimators': 250, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 15}, {'feature_extraction__n_components': 2, 'estimator__n_estimators': 200, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 10}, {'feature_extraction__n_components': 2, 'estimator__n_estimators': 200, 'estimator__max_features': 'log2', 'estimator__max_depth': 10}, {'feature_extraction__n_components': 1, 'estimator__n_estimators': 200, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 15}, {'feature_extraction__n_components': 2, 'estimator__n_estimators': 250, 'estimator__max_features': 'log2', 'estimator__max_depth': 15}, {'feature_extraction__n_components': 2, 'estimator__n_estimators': 200, 'estimator__max_features': 'log2', 'estimator__max_depth': 15}, {'feature_extraction__n_components': 1, 'estimator__n_estimators': 200, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 10}, {'feature_extraction__n_components': 2, 'estimator__n_estimators': 200, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 15}, {'feature_extraction__n_components': 1, 'estimator__n_estimators': 200, 'estimator__max_features': 'sqrt', 'estimator__max_depth': 10}, {'feature_extraction__n_components': 1, 'estimator__n_estimators': 200, 'estimator__max_features': 'log2', 'estimator__max_depth': 10}]"

# %%
filtered_df['estimator'][25]
# Out:
# "RandomForestRegressor(criterion = 'squared_error')"

# %%
filtered_df.iloc[2].best_params
# Out:
# "[{'feature_extraction__n_components': 4, 'estimator__tol': 0.0001, 'estimator__kernel': 'rbf', 'estimator__epsilon': 1e-05, 'estimator__C': 0.5}, {'feature_extraction__n_components': 4, 'estimator__tol': 0.001, 'estimator__kernel': 'rbf', 'estimator__epsilon': 0.001, 'estimator__C': 0.5}, {'feature_extraction__n_components': 5, 'estimator__tol': 0.001, 'estimator__kernel': 'rbf', 'estimator__epsilon': 0.01, 'estimator__C': 1.0}, {'feature_extraction__n_components': 4, 'estimator__tol': 0.001, 'estimator__kernel': 'rbf', 'estimator__epsilon': 0.001, 'estimator__C': 0.5}, {'feature_extraction__n_components': 5, 'estimator__tol': 0.0001, 'estimator__kernel': 'rbf', 'estimator__epsilon': 0.001, 'estimator__C': 0.5}, {'feature_extraction__n_components': 4, 'estimator__tol': 0.001, 'estimator__kernel': 'rbf', 'estimator__epsilon': 0.01, 'estimator__C': 0.5}, {'feature_extraction__n_components': 4, 'estimator__tol': 0.0001, 'estimator__kernel': 'rbf', 'estimator__epsilon': 1e-05, 'estimator__C': 1.0}, {'feature_extraction__n_components': 3, 'estimator__tol': 0.01, 'estimator__kernel': 'rbf', 'estimator__epsilon': 0.1, 'estimator__C': 0.25}, {'feature_extraction__n_components': 4, 'estimator__tol': 0.0001, 'estimator__kernel': 'rbf', 'estimator__epsilon': 1e-05, 'estimator__C': 0.5}, {'feature_extraction__n_components': 6, 'estimator__tol': 0.01, 'estimator__kernel': 'linear', 'estimator__epsilon': 0.01, 'estimator__C': 0.0625}]"
